# %%
# %%capture
# !apt-get update
# !apt-get install --reinstall build-essential --yes

# %%
# %%capture
# !pip install bertopic==0.11.0
# !pip install farm-haystack
# !pip install spacy
# !pip install gensim
# !pip install sagemaker_pyspark
# !python -m spacy download en_core_web_sm
# !pip install joblib==1.1.0

# %%
# %%capture
# !pip install wordcloud

# %%
import re
import string
import pickle
import logging
import pandas as pd
import plotly.io as pio
import matplotlib.pyplot as plt
import gensim.corpora as corpora

from umap import UMAP
from hdbscan import HDBSCAN
from bertopic import BERTopic
from nltk.corpus import stopwords
from haystack.nodes import PreProcessor
from nltk.corpus import PlaintextCorpusReader
from haystack.utils import convert_files_to_docs
from sentence_transformers import SentenceTransformer
from gensim.models.coherencemodel import CoherenceModel

pio.renderers.default='iframe'
logging.getLogger("haystack.utils.preprocessing").setLevel(logging.ERROR)
# Out:
# OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.
# WARNING:haystack.nodes.answer_generator.openai:OpenAI tiktoken module is not available for Python < 3.8,Linux ARM64 and AARCH64. Falling back to GPT2TokenizerFast.

# %%
import nltk

from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

nltk.download('wordnet')
nltk.download('omw-1.4')
token_pattern = re.compile(r"(?u)\b\w\w+\b")
sentence_model = SentenceTransformer("all-distilroberta-v1")

class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()

    def __call__(self, doc):
        return [
            self.wnl.lemmatize(t)
            for t in word_tokenize(doc)
            if (len(t) > 3 and re.match("[a-z].*", t) and re.match(token_pattern, t)) or (t=='ai')
        ]
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/vedantgupta/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/vedantgupta/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
output_path = "BERT_DTM/"
topic_model = BERTopic.load(output_path+"bert_dtm_model")

# %%
with open(output_path+'bert_dtm_timestamps.pkl', 'rb') as f:
    timestamps = pickle.load(f)
with open(output_path+'bert_dtm_prob.pkl', 'rb') as f:
    prob = pickle.load(f)
with open(output_path+'bert_dtm_coherence.pkl', 'rb') as f:
    coherence = pickle.load(f)
with open(output_path+'bert_dtm_topics.pkl', 'rb') as f:
    topic = pickle.load(f)
with open(output_path+'bert_dtm_hierarchical_topics.pkl', 'rb') as f:
    hierarchical_topics = pickle.load(f)
with open(output_path+'bert_dtm_docs.pkl', 'rb') as f:
    docs = pickle.load(f)

# %% [markdown]
# #### Topic Representation

# %%
# all topics
topic_model.get_topics()
# Out:
# {-1: [('company', 0.01825795768336218),
#   ('state', 0.011237502418052837),
#   ('people', 0.010831410624834663),
#   ('business', 0.010350426433472303),
#   ('percent', 0.010288128031216655),
#   ('worker', 0.009883718378177512),
#   ('work', 0.009828497690343996),
#   ('million', 0.009777492120925298),
#   ('system', 0.009161345233506677),
#   ('computer', 0.008911801725745752)],
#  0: [('company', 0.017173033349054352),
#   ('system', 0.011208811051923393),
#   ('worker', 0.010629439675019656),
#   ('state', 0.010169605299238306),
#   ('industry', 0.009922843923660805),
#   ('people', 0.009869677137974795),
#   ('computer', 0.009520152560694859),
#   ('union', 0.009416353995614638),
#   ('work', 0.009415577014842455),
#   ('american', 0.009303684057981217)],
#  1: [('theater', 0.020693451564253153),
#   ('music', 0.019208106514958103),
#   ('directed', 0.018805136410326283),
#   ('closed', 0.016180429669104338),
#   ('show', 0.01578674718836243),
#   ('street', 0.014342068736054852),
#   ('city', 0.013717290771941284),
#   ('museum', 0.012885802818129876),
#   ('york', 0.012846786604276754),
#   ('play', 0.012491449758354192)],
#  2: [('ship', 0.05576556657244579),
#   ('port', 0.03981673597777882),
#   ('union', 0.03811814242210627),
#   ('cargo', 0.030580390584695884),
#   ('longshoreman', 0.029278557059017902),
#   ('maritime', 0.0270195125085251),
#   ('shipping', 0.02426468277941231),
#   ('vessel', 0.023391552149053793),
#   ('marine', 0.02243119255739959),
#   ('container', 0.021631576559937592)],
#  3: [('union', 0.0731016813702368),
#   ('newspaper', 0.06871316118686954),
#   ('publisher', 0.04850410368701502),
#   ('news', 0.045028115602255496),
#   ('printer', 0.04286375347977118),
#   ('guild', 0.04076541360726225),
#   ('strike', 0.036105171178548424),
#   ('york', 0.03411614314828983),
#   ('contract', 0.03208073374742765),
#   ('paper', 0.028758231887172945)],
#  4: [('exchange', 0.0960801592210522),
#   ('stock', 0.06343931666057782),
#   ('trading', 0.05479056849537865),
#   ('market', 0.044272048959137646),
#   ('firm', 0.030135017554017676),
#   ('security', 0.02946165159926877),
#   ('board', 0.028639029254484163),
#   ('system', 0.024725207890798535),
#   ('floor', 0.02379574451552403),
#   ('brokerage', 0.020926259615464994)],
#  5: [('earns', 0.1817328649889363),
#   ('income', 0.1630187534707917),
#   ('sale', 0.11749119680245296),
#   ('share', 0.07679370005400309),
#   ('revenue', 0.0414544308142009),
#   ('loss', 0.0392865743194509),
#   ('quarter', 0.036088091331057504),
#   ('cent', 0.03138110752541202),
#   ('rev', 0.030506693653847405),
#   ('earnings', 0.026479280115702178)],
#  6: [('train', 0.0657395287101998),
#   ('transit', 0.04401733079014233),
#   ('subway', 0.04063845245336639),
#   ('authority', 0.03173845587697218),
#   ('system', 0.031070366543832023),
#   ('station', 0.030033011691827788),
#   ('railroad', 0.028287545696387906),
#   ('rider', 0.02475559549601651),
#   ('line', 0.024105961437571655),
#   ('fare', 0.023425795362271386)],
#  7: [('graduated', 0.078900768555031),
#   ('father', 0.07725718858344616),
#   ('bride', 0.07313374940186367),
#   ('mother', 0.05998917592196724),
#   ('university', 0.05657478387901035),
#   ('married', 0.048421514593624405),
#   ('daughter', 0.047158636953987726),
#   ('retired', 0.04310071572258828),
#   ('groom', 0.04240778721082545),
#   ('york', 0.04166985999169832)],
#  8: [('driving', 0.07771234790012761),
#   ('vehicle', 0.0658657442834816),
#   ('car', 0.056953039972977),
#   ('driver', 0.05530882148137258),
#   ('self', 0.048938445074271066),
#   ('autonomous', 0.04771281399212794),
#   ('uber', 0.03585034521007434),
#   ('technology', 0.032024623991647794),
#   ('google', 0.02835302012095738),
#   ('road', 0.025560887472571046)],
#  9: [('hospital', 0.05290267449014697),
#   ('patient', 0.04691350763415955),
#   ('health', 0.04573843989195417),
#   ('doctor', 0.039958103075114715),
#   ('drug', 0.03650025774585109),
#   ('care', 0.03641530792797531),
#   ('medical', 0.03560593935995218),
#   ('physician', 0.029280220097696152),
#   ('system', 0.01944135991870844),
#   ('test', 0.01866474951589993)],
#  10: [('president', 0.14440954580589552),
#   ('vice', 0.12672399320991903),
#   ('executive', 0.07293401408638271),
#   ('chief', 0.06677765936765345),
#   ('elected', 0.06551445444007933),
#   ('chairman', 0.0591012627086622),
#   ('officer', 0.052071741858103364),
#   ('appointed', 0.04740651053928999),
#   ('company', 0.040386241047478795),
#   ('senior', 0.03991061985411398)],
#  11: [('camera', 0.12295267164972665),
#   ('lens', 0.07900484230089481),
#   ('exposure', 0.05217329660777616),
#   ('film', 0.044803499027554435),
#   ('shutter', 0.038863591882821624),
#   ('photographer', 0.03245348649107389),
#   ('picture', 0.03135558511669252),
#   ('flash', 0.030509292899131405),
#   ('photography', 0.028604809588517202),
#   ('automatic', 0.02585914182251137)],
#  12: [('horse', 0.029051105594626342),
#   ('hunter', 0.029026008441218203),
#   ('game', 0.022053169166785867),
#   ('track', 0.021700450715403267),
#   ('player', 0.020030418498484324),
#   ('green', 0.0181636881927332),
#   ('championship', 0.01755001213772699),
#   ('conformation', 0.01738521172842997),
#   ('farm', 0.016954673271619543),
#   ('champion', 0.016907426317856945)],
#  13: [('postal', 0.1433512079544009),
#   ('mail', 0.09992386316401053),
#   ('service', 0.06279080151818965),
#   ('letter', 0.049145535016614485),
#   ('post', 0.04163239422096301),
#   ('office', 0.03749411186004019),
#   ('postmaster', 0.03016391651256678),
#   ('rate', 0.026882989275525727),
#   ('sorting', 0.02619448483628109),
#   ('code', 0.02332959929308511)],
#  14: [('call', 0.07511582231644445),
#   ('phone', 0.0555821173378101),
#   ('customer', 0.042501096432822745),
#   ('voice', 0.04229542269059322),
#   ('number', 0.04088704780234751),
#   ('service', 0.0386655283686125),
#   ('telephone', 0.027540785265764672),
#   ('message', 0.02495759764298451),
#   ('mail', 0.02401250636112984),
#   ('caller', 0.023797811628394762)],
#  15: [('toll', 0.14882312376327042),
#   ('zpass', 0.07650912217815013),
#   ('bridge', 0.06626949713013604),
#   ('jersey', 0.0576201093882761),
#   ('turnpike', 0.05300926357118017),
#   ('system', 0.04322538879362436),
#   ('authority', 0.04185206336709331),
#   ('lane', 0.04114611378497416),
#   ('state', 0.037185565316330174),
#   ('highway', 0.03597820460680421)],
#  16: [('police', 0.06463393034218012),
#   ('fingerprint', 0.028208250706457046),
#   ('criminal', 0.027444539919086818),
#   ('crime', 0.026512682202132674),
#   ('camera', 0.02489245027560333),
#   ('system', 0.023998280823502107),
#   ('court', 0.022226712762887773),
#   ('department', 0.02174011074979751),
#   ('enforcement', 0.02055051936128682),
#   ('city', 0.020187702937492887)]}

# %%
# listing all topics
for i in range(18):
    print("Topic "+ str(i-1) + ":")
    print()
    print("Representative Words:")
    print(topic_model.get_topic(i-1))
    print()
    print("Topic Info:")
    print(topic_model.get_topic_info(i-1))
    print()
# Out:
# Topic -1:
#
# Representative Words:
# [('company', 0.01825795768336218), ('state', 0.011237502418052837), ('people', 0.010831410624834663), ('business', 0.010350426433472303), ('percent', 0.010288128031216655), ('worker', 0.009883718378177512), ('work', 0.009828497690343996), ('million', 0.009777492120925298), ('system', 0.009161345233506677), ('computer', 0.008911801725745752)]
#
# Topic Info:
#    Topic  Count                              Name
# 0     -1   5072  -1_company_state_people_business
#
# Topic 0:
#
# Representative Words:
# [('company', 0.017173033349054352), ('system', 0.011208811051923393), ('worker', 0.010629439675019656), ('state', 0.010169605299238306), ('industry', 0.009922843923660805), ('people', 0.009869677137974795), ('computer', 0.009520152560694859), ('union', 0.009416353995614638), ('work', 0.009415577014842455), ('american', 0.009303684057981217)]
#
# Topic Info:
#     Topic  Count                                  Name
# 0      -1   5072      -1_company_state_people_business
# 1       0   4414         0_company_system_worker_state
# 2       1    647       1_theater_music_directed_closed
# 3       2    497               2_ship_port_union_cargo
# 4       3    460      3_union_newspaper_publisher_news
# 5       4    404       4_exchange_stock_trading_market
# 6       5    267             5_earns_income_sale_share
# 7       6    218      6_train_transit_subway_authority
# 8       7    174       7_graduated_father_bride_mother
# 9       8    170          8_driving_vehicle_car_driver
# 10      9    159      9_hospital_patient_health_doctor
# 11     10    151     10_president_vice_executive_chief
# 12     11    142          11_camera_lens_exposure_film
# 13     12    138            12_horse_hunter_game_track
# 14     13     84         13_postal_mail_service_letter
# 15     14     69          14_call_phone_customer_voice
# 16     15     64           15_toll_zpass_bridge_jersey
# 17     16     61  16_police_fingerprint_criminal_crime
#
# Topic 1:
#
# Representative Words:
# [('theater', 0.020693451564253153), ('music', 0.019208106514958103), ('directed', 0.018805136410326283), ('closed', 0.016180429669104338), ('show', 0.01578674718836243), ('street', 0.014342068736054852), ('city', 0.013717290771941284), ('museum', 0.012885802818129876), ('york', 0.012846786604276754), ('play', 0.012491449758354192)]
#
# Topic Info:
#    Topic  Count                             Name
# 0      1    647  1_theater_music_directed_closed
#
# Topic 2:
#
# Representative Words:
# [('ship', 0.05576556657244579), ('port', 0.03981673597777882), ('union', 0.03811814242210627), ('cargo', 0.030580390584695884), ('longshoreman', 0.029278557059017902), ('maritime', 0.0270195125085251), ('shipping', 0.02426468277941231), ('vessel', 0.023391552149053793), ('marine', 0.02243119255739959), ('container', 0.021631576559937592)]
#
# Topic Info:
#    Topic  Count                     Name
# 0      2    497  2_ship_port_union_cargo
#
# Topic 3:
#
# Representative Words:
# [('union', 0.0731016813702368), ('newspaper', 0.06871316118686954), ('publisher', 0.04850410368701502), ('news', 0.045028115602255496), ('printer', 0.04286375347977118), ('guild', 0.04076541360726225), ('strike', 0.036105171178548424), ('york', 0.03411614314828983), ('contract', 0.03208073374742765), ('paper', 0.028758231887172945)]
#
# Topic Info:
#    Topic  Count                              Name
# 0      3    460  3_union_newspaper_publisher_news
#
# Topic 4:
#
# Representative Words:
# [('exchange', 0.0960801592210522), ('stock', 0.06343931666057782), ('trading', 0.05479056849537865), ('market', 0.044272048959137646), ('firm', 0.030135017554017676), ('security', 0.02946165159926877), ('board', 0.028639029254484163), ('system', 0.024725207890798535), ('floor', 0.02379574451552403), ('brokerage', 0.020926259615464994)]
#
# Topic Info:
#    Topic  Count                             Name
# 0      4    404  4_exchange_stock_trading_market
#
# Topic 5:
#
# Representative Words:
# [('earns', 0.1817328649889363), ('income', 0.1630187534707917), ('sale', 0.11749119680245296), ('share', 0.07679370005400309), ('revenue', 0.0414544308142009), ('loss', 0.0392865743194509), ('quarter', 0.036088091331057504), ('cent', 0.03138110752541202), ('rev', 0.030506693653847405), ('earnings', 0.026479280115702178)]
#
# Topic Info:
#    Topic  Count                       Name
# 0      5    267  5_earns_income_sale_share
#
# Topic 6:
#
# Representative Words:
# [('train', 0.0657395287101998), ('transit', 0.04401733079014233), ('subway', 0.04063845245336639), ('authority', 0.03173845587697218), ('system', 0.031070366543832023), ('station', 0.030033011691827788), ('railroad', 0.028287545696387906), ('rider', 0.02475559549601651), ('line', 0.024105961437571655), ('fare', 0.023425795362271386)]
#
# Topic Info:
#    Topic  Count                              Name
# 0      6    218  6_train_transit_subway_authority
#
# Topic 7:
#
# Representative Words:
# [('graduated', 0.078900768555031), ('father', 0.07725718858344616), ('bride', 0.07313374940186367), ('mother', 0.05998917592196724), ('university', 0.05657478387901035), ('married', 0.048421514593624405), ('daughter', 0.047158636953987726), ('retired', 0.04310071572258828), ('groom', 0.04240778721082545), ('york', 0.04166985999169832)]
#
# Topic Info:
#    Topic  Count                             Name
# 0      7    174  7_graduated_father_bride_mother
#
# Topic 8:
#
# Representative Words:
# [('driving', 0.07771234790012761), ('vehicle', 0.0658657442834816), ('car', 0.056953039972977), ('driver', 0.05530882148137258), ('self', 0.048938445074271066), ('autonomous', 0.04771281399212794), ('uber', 0.03585034521007434), ('technology', 0.032024623991647794), ('google', 0.02835302012095738), ('road', 0.025560887472571046)]
#
# Topic Info:
#    Topic  Count                          Name
# 0      8    170  8_driving_vehicle_car_driver
#
# Topic 9:
#
# Representative Words:
# [('hospital', 0.05290267449014697), ('patient', 0.04691350763415955), ('health', 0.04573843989195417), ('doctor', 0.039958103075114715), ('drug', 0.03650025774585109), ('care', 0.03641530792797531), ('medical', 0.03560593935995218), ('physician', 0.029280220097696152), ('system', 0.01944135991870844), ('test', 0.01866474951589993)]
#
# Topic Info:
#    Topic  Count                              Name
# 0      9    159  9_hospital_patient_health_doctor
#
# Topic 10:
#
# Representative Words:
# [('president', 0.14440954580589552), ('vice', 0.12672399320991903), ('executive', 0.07293401408638271), ('chief', 0.06677765936765345), ('elected', 0.06551445444007933), ('chairman', 0.0591012627086622), ('officer', 0.052071741858103364), ('appointed', 0.04740651053928999), ('company', 0.040386241047478795), ('senior', 0.03991061985411398)]
#
# Topic Info:
#    Topic  Count                               Name
# 0     10    151  10_president_vice_executive_chief
#
# Topic 11:
#
# Representative Words:
# [('camera', 0.12295267164972665), ('lens', 0.07900484230089481), ('exposure', 0.05217329660777616), ('film', 0.044803499027554435), ('shutter', 0.038863591882821624), ('photographer', 0.03245348649107389), ('picture', 0.03135558511669252), ('flash', 0.030509292899131405), ('photography', 0.028604809588517202), ('automatic', 0.02585914182251137)]
#
# Topic Info:
#    Topic  Count                          Name
# 0     11    142  11_camera_lens_exposure_film
#
# Topic 12:
#
# Representative Words:
# [('horse', 0.029051105594626342), ('hunter', 0.029026008441218203), ('game', 0.022053169166785867), ('track', 0.021700450715403267), ('player', 0.020030418498484324), ('green', 0.0181636881927332), ('championship', 0.01755001213772699), ('conformation', 0.01738521172842997), ('farm', 0.016954673271619543), ('champion', 0.016907426317856945)]
#
# Topic Info:
#    Topic  Count                        Name
# 0     12    138  12_horse_hunter_game_track
#
# Topic 13:
#
# Representative Words:
# [('postal', 0.1433512079544009), ('mail', 0.09992386316401053), ('service', 0.06279080151818965), ('letter', 0.049145535016614485), ('post', 0.04163239422096301), ('office', 0.03749411186004019), ('postmaster', 0.03016391651256678), ('rate', 0.026882989275525727), ('sorting', 0.02619448483628109), ('code', 0.02332959929308511)]
#
# Topic Info:
#    Topic  Count                           Name
# 0     13     84  13_postal_mail_service_letter
#
# Topic 14:
#
# Representative Words:
# [('call', 0.07511582231644445), ('phone', 0.0555821173378101), ('customer', 0.042501096432822745), ('voice', 0.04229542269059322), ('number', 0.04088704780234751), ('service', 0.0386655283686125), ('telephone', 0.027540785265764672), ('message', 0.02495759764298451), ('mail', 0.02401250636112984), ('caller', 0.023797811628394762)]
#
# Topic Info:
#    Topic  Count                          Name
# 0     14     69  14_call_phone_customer_voice
#
# Topic 15:
#
# Representative Words:
# [('toll', 0.14882312376327042), ('zpass', 0.07650912217815013), ('bridge', 0.06626949713013604), ('jersey', 0.0576201093882761), ('turnpike', 0.05300926357118017), ('system', 0.04322538879362436), ('authority', 0.04185206336709331), ('lane', 0.04114611378497416), ('state', 0.037185565316330174), ('highway', 0.03597820460680421)]
#
# Topic Info:
#    Topic  Count                         Name
# 0     15     64  15_toll_zpass_bridge_jersey
#
# Topic 16:
#
# Representative Words:
# [('police', 0.06463393034218012), ('fingerprint', 0.028208250706457046), ('criminal', 0.027444539919086818), ('crime', 0.026512682202132674), ('camera', 0.02489245027560333), ('system', 0.023998280823502107), ('court', 0.022226712762887773), ('department', 0.02174011074979751), ('enforcement', 0.02055051936128682), ('city', 0.020187702937492887)]
#
# Topic Info:
#    Topic  Count                                  Name
# 0     16     61  16_police_fingerprint_criminal_crime

# %% [markdown]
# #### Visualize Topics

# %%
folder_path = r'/Users/vedantgupta/Desktop/Oncampus - Research/nyt-topic-modeling-main/Topic Modeling Code/BERT/BERTDTM_FIGURES/'

# %%
# Topic distance map
fig = topic_model.visualize_topics()
fig.write_html(folder_path+'Intertopic_Distance_Map.html')

# %%
# representative words with probability for each topic
fig = topic_model.visualize_barchart(top_n_topics=17)
fig.write_html(folder_path+'Topic_Word_Score.html')

# %%
# Need embeddings for this
topic_model.visualize_documents(docs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lp/czc_kj497yqglt4zlns7jtr00000gn/T/ipykernel_43801/3062248876.py in <module>
#       1 # Need embeddings for this
# ----> 2 topic_model.visualize_documents(docs)
#
# ~/opt/anaconda3/envs/oncampusR/lib/python3.7/site-packages/bertopic/_bertopic.py in visualize_documents(self, docs, topics, embeddings, reduced_embeddings, sample, hide_annotations, hide_document_hover, custom_labels, width, height)
#    1432                                             custom_labels=custom_labels,
#    1433                                             width=width,
# -> 1434                                             height=height)
#    1435
#    1436     def visualize_hierarchical_documents(self,
#
# ~/opt/anaconda3/envs/oncampusR/lib/python3.7/site-packages/bertopic/plotting/_documents.py in visualize_documents(topic_model, docs, topics, embeddings, reduced_embeddings, sample, hide_annotations, hide_document_hover, custom_labels, width, height)
#     113             embeddings_to_reduce = embeddings[indices]
#     114         elif embeddings is None and reduced_embeddings is None:
# --> 115             embeddings_to_reduce = topic_model._extract_embeddings(df.doc.to_list(), method="document")
#     116
#     117     # Reduce input embeddings
#
# ~/opt/anaconda3/envs/oncampusR/lib/python3.7/site-packages/bertopic/_bertopic.py in _extract_embeddings(self, documents, method, verbose)
#    2033             embeddings = self.embedding_model.embed_words(documents, verbose)
#    2034         elif method == "document":
# -> 2035             embeddings = self.embedding_model.embed_documents(documents, verbose)
#    2036         else:
#    2037             raise ValueError("Wrong method for extracting document/word embeddings. "
#
# AttributeError: 'NoneType' object has no attribute 'embed_documents'

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
def get_topic_word_cloud(topic_model, topic_number):
    word_freq = topic_model.get_topic(topic_number)
    word_freq = {w:f for w, f in word_freq}
    wordcloud = WordCloud(stopwords = STOPWORDS, background_color='white')
    wordcloud.generate_from_frequencies(word_freq)
    wordcloud.to_file(folder_path+'Topic_'+str(topic_number)+'_wordclound.png')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
# word cloud for each topic
for i in range(18):
    print('Topic: ' + str(i-1))
    get_topic_word_cloud(topic_model, i-1)
    print('******************************')
# Out:
# Topic: -1
# ******************************
# Topic: 0
# ******************************
# Topic: 1
# ******************************
# Topic: 2
# ******************************
# Topic: 3
# ******************************
# Topic: 4
# ******************************
# Topic: 5
# ******************************
# Topic: 6
# ******************************
# Topic: 7
# ******************************
# Topic: 8
# ******************************
# Topic: 9
# ******************************
# Topic: 10
# ******************************
# Topic: 11
# ******************************
# Topic: 12
# ******************************
# Topic: 13
# ******************************
# Topic: 14
# ******************************
# Topic: 15
# ******************************
# Topic: 16
# ******************************

# %%
# need embeddings
topic_model.visualize_hierarchical_documents(docs, hierarchical_topics)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lp/czc_kj497yqglt4zlns7jtr00000gn/T/ipykernel_43801/2623552650.py in <module>
#       1 # need embeddings
# ----> 2 topic_model.visualize_hierarchical_documents(docs, hierarchical_topics)
#
# ~/opt/anaconda3/envs/oncampusR/lib/python3.7/site-packages/bertopic/_bertopic.py in visualize_hierarchical_documents(self, docs, hierarchical_topics, topics, embeddings, reduced_embeddings, sample, hide_annotations, hide_document_hover, nr_levels, custom_labels, width, height)
#    1538                                                          custom_labels=custom_labels,
#    1539                                                          width=width,
# -> 1540                                                          height=height)
#    1541
#    1542     def visualize_term_rank(self,
#
# ~/opt/anaconda3/envs/oncampusR/lib/python3.7/site-packages/bertopic/plotting/_hierarchical_documents.py in visualize_hierarchical_documents(topic_model, docs, hierarchical_topics, topics, embeddings, reduced_embeddings, sample, hide_annotations, hide_document_hover, nr_levels, custom_labels, width, height)
#     129             embeddings_to_reduce = embeddings[indices]
#     130         elif embeddings is None and reduced_embeddings is None:
# --> 131             embeddings_to_reduce = topic_model._extract_embeddings(df.doc.to_list(), method="document")
#     132
#     133     # Reduce input embeddings
#
# ~/opt/anaconda3/envs/oncampusR/lib/python3.7/site-packages/bertopic/_bertopic.py in _extract_embeddings(self, documents, method, verbose)
#    2033             embeddings = self.embedding_model.embed_words(documents, verbose)
#    2034         elif method == "document":
# -> 2035             embeddings = self.embedding_model.embed_documents(documents, verbose)
#    2036         else:
#    2037             raise ValueError("Wrong method for extracting document/word embeddings. "
#
# AttributeError: 'NoneType' object has no attribute 'embed_documents'

# %%
# heirarchical topics
fig = topic_model.visualize_hierarchy(hierarchical_topics=hierarchical_topics)
fig.write_html(folder_path+'Hierarchical_Clustering.html')

# %%
# topic tree
tree = topic_model.get_topic_tree(hierarchical_topics)

# %%
print(tree)
# Out:
# .
# ├─earns_income_sale_share_president
# │    ├─■──earns_income_sale_share_revenue ── Topic: 5
# │    └─president_vice_father_graduated_executive
# │         ├─■──president_vice_executive_chief_elected ── Topic: 10
# │         └─■──graduated_father_bride_mother_university ── Topic: 7
# └─company_union_system_york_work
#      ├─company_union_system_york_work
#      │    ├─exchange_stock_trading_market_system
#      │    │    ├─■──postal_mail_service_letter_post ── Topic: 13
#      │    │    └─exchange_stock_trading_market_system
#      │    │         ├─hospital_patient_health_doctor_care
#      │    │         │    ├─■──call_phone_customer_voice_number ── Topic: 14
#      │    │         │    └─■──hospital_patient_health_doctor_drug ── Topic: 9
#      │    │         └─■──exchange_stock_trading_market_firm ── Topic: 4
#      │    └─company_union_system_work_york
#      │         ├─union_newspaper_ship_york_strike
#      │         │    ├─■──union_newspaper_publisher_news_printer ── Topic: 3
#      │         │    └─■──ship_port_union_cargo_longshoreman ── Topic: 2
#      │         └─company_system_work_state_people
#      │              ├─company_system_worker_state_people
#      │              │    ├─train_transit_subway_system_authority
#      │              │    │    ├─■──police_fingerprint_criminal_crime_camera ── Topic: 16
#      │              │    │    └─■──train_transit_subway_authority_system ── Topic: 6
#      │              │    └─■──company_system_worker_state_industry ── Topic: 0
#      │              └─theater_music_directed_show_closed
#      │                   ├─■──theater_music_directed_closed_show ── Topic: 1
#      │                   └─■──horse_hunter_game_track_player ── Topic: 12
#      └─camera_driving_lens_vehicle_driver
#           ├─driving_vehicle_driver_car_self
#           │    ├─■──toll_zpass_bridge_jersey_turnpike ── Topic: 15
#           │    └─■──driving_vehicle_car_driver_self ── Topic: 8
#           └─■──camera_lens_exposure_film_shutter ── Topic: 11

# %%
# topic similarity
fig = topic_model.visualize_heatmap()
fig.write_html(folder_path+'Heat_Map.html')

# %%
# if we keep adding words to topic name how score decreases
fig = topic_model.visualize_term_rank()
fig.write_html(folder_path+'Term_Score_Decline.html')

# %%
fig = topic_model.visualize_term_rank(log_scale=True)
fig.write_html(folder_path+'Term_Score_Decline_log_scale.html')

# %%
# topic prob distribution
fig = topic_model.visualize_distribution(prob[0], min_probability=0)
fig.write_html(folder_path+'Prob_distribution.html')

# %%
# topic over time
topics_over_time = topic_model.topics_over_time(docs=docs, 
                                                topics=topic, 
                                                timestamps=timestamps, 
                                                )
# Out:
# 6it [01:14, 11.59s/it]

# %%
topic_model.visualize_topics_over_time(topics_over_time, top_n_topics=50, normalize_frequency=False)
# Out:
# <iframe
#     scrolling="no"
#     width="1270px"
#     height="470"
#     src="iframe_figures/figure_51.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
def compare_topic_freq(topic_to_compare_with, topic_being_compared, normalize_freq = False):
    ''' You can compare the freq of topics you want.
        topic_to_compare_with -> INT
        topic_being_compared -> List[INT]
        normalize_freq -> bool
    '''
    topic_being_compared.append(topic_to_compare_with)
    return topic_model.visualize_topics_over_time(topics_over_time, normalize_frequency=normalize_freq, topics=topic_being_compared)

# %%
def get_comparison(topic_to_compare_with, normalize_freq = False):
    plots = []
    idx = 0
    while idx < 17:
        if idx == topic_to_compare_with:
            idx += 1
            continue
        topic_being_compared = []
        topic_being_compared.append(idx)
        topic_being_compared.append(topic_to_compare_with)
        plots.append(topic_model.visualize_topics_over_time(topics_over_time, normalize_frequency=normalize_freq, topics=topic_being_compared))
        idx += 1
    return plots

# %%
'''The code below compares the frequency of one topic with other topics and is saved in a folder.'''
# Out:
# 'The code below compares the frequency of one topic with other topics and is saved in a folder.'

# %%
all_plots = {}
for i in range(17):
    all_plots[i] = get_comparison(i)

# %%
folder_path = r'/Users/vedantgupta/Desktop/Oncampus - Research/nyt-topic-modeling-main/Topic Modeling Code/BERT/Freq comparison BERTopic'

# %%
for key, val in all_plots.items():
    for i in range(len(val)):
        val[i].write_html(folder_path+"/"+str(key)+"_"+str(i+1)+".html")
